# %%
import pandas as pd

# %%
dataset = pd.read_csv('cosmetic_p.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1472 entries, 0 to 1471
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Label        1472 non-null   object
#  1   brand        1472 non-null   object
#  2   name         1472 non-null   object
#  3   price        1472 non-null   int64
#  4   rank         1472 non-null   float64
#  5   ingredients  1472 non-null   object
#  6   Combination  1472 non-null   int64
#  7   Dry          1472 non-null   int64
#  8   Normal       1472 non-null   int64
#  9   Oily         1472 non-null   int64
#  10  Sensitive    1472 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 126.6+ KB

# %%
dataset.isna().any()
# Out:
# Label          False
# brand          False
# name           False
# price          False
# rank           False
# ingredients    False
# Combination    False
# Dry            False
# Normal         False
# Oily           False
# Sensitive      False
# dtype: bool

# %%
dataset.head()
# Out:
#        Label               brand  \
# 0  Face Mask         ERNO LASZLO
# 1  Treatment               FRESH
# 2   Cleanser  KIEHL'S SINCE 1851
# 3  Eye cream  KIEHL'S SINCE 1851
# 4  Eye cream          L'OCCITANE
#
#                                                 name  price  rank  \
# 0        Hydra-Therapy Skin Vitality Treatment Masks     88   4.3
# 1              Umbrian Clay Pore Purifying Face Mask     58   4.4
# 2  Clearly Correctiveâ„¢ Brightening & Exfoliatin...     29   4.3
# 3                                           Eye Fuel     22   4.0
# 4                                Immortelle Eye Balm     44   4.1
#
#                                          ingredients  Combination  Dry  \
# 0  ["Magnesium Carbonate, Allantoin: A healing an...            1    1
# 1  ["Solum Fullonum (Fuller's Earth)", 'Aqua (Wat...            0    0
# 2          ["Visit the Kiehl's Since 1851 boutique"]            1    1
# 3          ["Visit the Kiehl's Since 1851 boutique"]            1    1
# ...

# %%
labels = dataset['Label']

# %%
labels.drop_duplicates()
# Out:
# 0       Face Mask
# 1       Treatment
# 2        Cleanser
# 3       Eye cream
# 6     Moisturizer
# 15    Sun protect
# Name: Label, dtype: object

# %%
dataset['brand'].nunique()
# Out:
# 116

# %%
min_price = dataset['price'].min()
min_price
# Out:
# 3

# %%
max_price = dataset['price'].max()
max_price
# Out:
# 370

# %%
min_rank = dataset['rank'].min()
min_rank
# Out:
# 0.0

# %%
max_rank = dataset['rank'].max()
max_rank
# Out:
# 5.0

# %%
no_info = dataset.loc[(dataset['ingredients'] == 'No Info')]
no_info.count(axis='rows')
# Out:
# Label          0
# brand          0
# name           0
# price          0
# rank           0
# ingredients    0
# Combination    0
# Dry            0
# Normal         0
# Oily           0
# Sensitive      0
# dtype: int64

# %%
visit = dataset[dataset['ingredients'].str.startswith('Visit') == False]
visit
# Out:
#             Label                      brand  \
# 0       Face Mask                ERNO LASZLO
# 1       Treatment                      FRESH
# 2        Cleanser         KIEHL'S SINCE 1851
# 3       Eye cream         KIEHL'S SINCE 1851
# 4       Eye cream                 L'OCCITANE
# ...           ...                        ...
# 1467     Cleanser                     KORRES
# 1468  Moisturizer           FIRST AID BEAUTY
# 1469  Sun protect  DR. DENNIS GROSS SKINCARE
# 1470    Treatment              HUM NUTRITION
# 1471    Treatment                      FRESH
#
#                                                    name  price  rank  \
# 0           Hydra-Therapy Skin Vitality Treatment Masks     88   4.3
# 1                 Umbrian Clay Pore Purifying Face Mask     58   4.4
# 2     Clearly Correctiveâ„¢ Brightening & Exfoliatin...     29   4.3
# 3                                              Eye Fuel     22   4.0
# 4                                   Immortelle Eye Balm     44   4.1
# ...

# %%
no_info = pd.Series(dataset['ingredients'])
num = no_info.str.startswith('Visit')

# %%
dataset['name'].is_unique
# Out:
# True

# %%
filtered = dataset[(dataset['ingredients'] != 'No Info') & (dataset['ingredients'].str.startswith('Visit') == False) ]
check = filtered[(filtered['ingredients'] == 'No Info') & (dataset['ingredients'].str.startswith('Visit') == True)]
check
filtered
# Out:
#             Label                      brand  \
# 0       Face Mask                ERNO LASZLO
# 1       Treatment                      FRESH
# 2        Cleanser         KIEHL'S SINCE 1851
# 3       Eye cream         KIEHL'S SINCE 1851
# 4       Eye cream                 L'OCCITANE
# ...           ...                        ...
# 1467     Cleanser                     KORRES
# 1468  Moisturizer           FIRST AID BEAUTY
# 1469  Sun protect  DR. DENNIS GROSS SKINCARE
# 1470    Treatment              HUM NUTRITION
# 1471    Treatment                      FRESH
#
#                                                    name  price  rank  \
# 0           Hydra-Therapy Skin Vitality Treatment Masks     88   4.3
# 1                 Umbrian Clay Pore Purifying Face Mask     58   4.4
# 2     Clearly Correctiveâ„¢ Brightening & Exfoliatin...     29   4.3
# 3                                              Eye Fuel     22   4.0
# 4                                   Immortelle Eye Balm     44   4.1
# ...

# %%
filtered.to_csv(r'C:\Users\User\Desktop\završni rad\filtered_dataset.csv', index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3448/947057323.py in <module>
# ----> 1 filtered.to_csv(r'C:\Users\User\Desktop\završni rad\filtered_dataset.csv', index=False, header=True)
#
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...
